# %%
import pandas as pd 
import numpy as np

# %%
df = np.round(pd.read_csv('50_Startups.csv')[['R&D Spend','Administration','Marketing Spend','Profit']]/10000)
df.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend  Profit
# 0       17.0            14.0             47.0    19.0
# 1       16.0            15.0             44.0    19.0
# 2       15.0            10.0             41.0    19.0

# %%
# df = df.iloc[:,0:-1]
df.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0       17.0            14.0             47.0
# 1       16.0            15.0             44.0
# 2       15.0            10.0             41.0

# %%
df.iloc[1,0] = np.nan
df.iloc[3,1] = np.nan
df.iloc[-1,-1] = np.nan

# %%
df.head(2)
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0       17.0            14.0             47.0
# 1        NaN            15.0             44.0

# %%
## Step - 1 - impute all missing Values with mean of respective col 
df_0 = pd.DataFrame()

df_0['R&D Spend'] = df['R&D Spend'].fillna(df['R&D Spend'].mean())
df_0['Administration'] = df['Administration'].fillna(df['Administration'].mean())
df_0['Marketing Spend'] = df['Marketing Spend'].fillna(df['Marketing Spend'].mean())

# %%
# 0th Iteration 
df_0.sample(3)
# Out:
#     R&D Spend  Administration  Marketing Spend
# 48        0.0             5.0              0.0
# 15       11.0            12.0             26.0
# 46        0.0            12.0             30.0

# %%
## Remove The col1 imputed Value 

df1 = df_0.copy()
df1.iloc[1,0] = np.nan
df1.head(3)
# Out:
#    R&D Spend  Administration  Marketing Spend
# 0       17.0            14.0             47.0
# 1        NaN            15.0             44.0
# 2       15.0            10.0             41.0

# %%
## use first 3 rows to build a model and use the last for prediction 
x = df1.iloc[[0,2,3,4],1:3]
x
# Out:
#    Administration  Marketing Spend
# 0       14.000000             47.0
# 2       10.000000             41.0
# 3       12.163265             38.0
# 4        9.000000             37.0

# %%
y = df1.iloc[[0,2,3,4],0]

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(x,y)
lr.predict(df1.iloc[1,1:].values.reshape(1,2))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.90294324])

# %%
df1.iloc[1,0] = 15.90

# %%
# remove the col2 imputed values 
df1.iloc[3,1] = np.nan

# %%
x = df1.iloc[[0,1,2,4],[0,2]]
x
# Out:
#    R&D Spend  Marketing Spend
# 0       17.0             47.0
# 1       15.9             44.0
# 2       15.0             41.0
# 4       14.0             37.0

# %%
y = df1.iloc[[0,1,2,4],1]

# %%
lr.fit(x,y)
lr.predict(df1.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.16743119])

# %%
df1.iloc[3,1] = 10.167

# %%
df1.iloc[4,-1] = np.nan

# %%
x = df1.iloc[0:4, 0:2]

# %%
y = df1.iloc[0:4,-1]

# %%
lr.fit(x,y)
lr.predict(df1.iloc[4,0:2].values.reshape(1,2))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37.95993759])

# %%
df1.iloc[4,-1] = 37.95

# %%
df1 - df_0
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0    0.000000        0.000000             0.00
# 1    8.736735        0.000000             0.00
# 2    0.000000        0.000000             0.00
# 3    0.000000       -1.996265             0.00
# 4    0.000000        0.000000             0.95
# 5    0.000000        0.000000             0.00
# 6    0.000000        0.000000             0.00
# 7    0.000000        0.000000             0.00
# 8    0.000000        0.000000             0.00
# 9    0.000000        0.000000             0.00
# 10   0.000000        0.000000             0.00
# 11   0.000000        0.000000             0.00
# 12   0.000000        0.000000             0.00
# 13   0.000000        0.000000             0.00
# 14   0.000000        0.000000             0.00
# 15   0.000000        0.000000             0.00
# 16   0.000000        0.000000             0.00
# 17   0.000000        0.000000             0.00
# 18   0.000000        0.000000             0.00
# ...

# %%
df2 = df1.copy()
df2.iloc[1,0] = np.nan

# %%
x = df2.iloc[[0,2,3,4],1:3]
y = df2.iloc[[0,2,3,4], 0]

lr.fit(x,y)
lr.predict(df2.iloc[1,1:].values.reshape(1,2))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.99212123])

# %%
df2.iloc[1,0] = 15.99

# %%
df2.iloc[3,1] = np.nan
X = df2.iloc[[0,1,2,4],[0,2]]
y = df2.iloc[[0,1,2,4],1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[3,[0,2]].values.reshape(1,2))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([10.15779719])

# %%
df2.iloc[3,1] = 19.22

# %%
df2.iloc[4,-1] = np.nan

X = df2.iloc[0:4,0:2]
y = df2.iloc[0:4,-1]

lr = LinearRegression()
lr.fit(X,y)
lr.predict(df2.iloc[4,0:2].values.reshape(1,2))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([37.99747686])

# %%
df2.iloc[4,-1] = 37.99

# %%
df2 - df1
# Out:
#     R&D Spend  Administration  Marketing Spend
# 0        0.00           0.000             0.00
# 1        0.09           0.000             0.00
# 2        0.00           0.000             0.00
# 3        0.00           9.053             0.00
# 4        0.00           0.000             0.04
# 5        0.00           0.000             0.00
# 6        0.00           0.000             0.00
# 7        0.00           0.000             0.00
# 8        0.00           0.000             0.00
# 9        0.00           0.000             0.00
# 10       0.00           0.000             0.00
# 11       0.00           0.000             0.00
# 12       0.00           0.000             0.00
# 13       0.00           0.000             0.00
# 14       0.00           0.000             0.00
# 15       0.00           0.000             0.00
# 16       0.00           0.000             0.00
# 17       0.00           0.000             0.00
# 18       0.00           0.000             0.00
# ...
