# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl.metadata (19 kB)
# ...
#   Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
# Using cached pandas-2.2.3-cp313-cp313-win_amd64.whl (11.5 MB)
# Using cached numpy-2.2.6-cp313-cp313-win_amd64.whl (12.6 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# ...
#
#    ---------------------------------------- 0/4 [pytz]
#    ---------------------------------------- 0/4 [pytz]
#    ---------- ----------------------------- 1/4 [tzdata]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
#    -------------------- ------------------- 2/4 [numpy]
# ...

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# ...
#   Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl.metadata (9.1 kB)
# ...
#   Using cached pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    -------------------------------------- - 7.9/8.1 MB 45.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 38.0 MB/s eta 0:00:00
# ...
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---------------------------------------- 2.2/2.2 MB 29.2 MB/s eta 0:00:00
# Using cached kiwisolver-1.4.8-cp313-cp313-win_amd64.whl (71 kB)
# Using cached pillow-11.2.1-cp313-cp313-win_amd64.whl (2.7 MB)
# Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# ...
#
#    ---------------------------------------- 0/7 [pyparsing]
# ...

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('placement.csv')

# %%
df.head(2)
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98

# %%
plt.scatter(df['cgpa'], df['package'])
plt.xlabel('CGPA')
plt.ylabel('Package (In LPA)')
# Out:
# Text(0, 0.5, 'Package (In LPA)')

# %%
## seperate your X and Y columns 
X = df.iloc[:,0:1]
Y = df.iloc[:,-1]

# %%
X
Y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
# %pip install scikit-learn
# Out:
# ...
#   Using cached scikit_learn-1.6.1-cp313-cp313-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached scipy-1.15.3-cp313-cp313-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached joblib-1.5.0-py3-none-any.whl.metadata (5.6 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Using cached scikit_learn-1.6.1-cp313-cp313-win_amd64.whl (11.1 MB)
# Using cached joblib-1.5.0-py3-none-any.whl (307 kB)
# Using cached scipy-1.15.3-cp313-cp313-win_amd64.whl (41.0 MB)
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# ...
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test,y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=2)

## Important to split data in 2 parts - training and testing

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression() ## linear regreesion

# %%
lr.fit(X_train, y_train) ## giving variables [column]
# Out:
# LinearRegression()

# %%
X_test
# Out:
#      cgpa
# 112  8.58
# 29   7.15
# 182  5.88
# 199  6.22
# 193  4.57
# 85   4.79
# 10   5.32
# 54   6.86
# 115  8.35
# 35   6.87
# 12   8.94
# 92   7.90
# 13   6.93
# 126  5.91
# 174  7.32
# 2    7.82
# 44   5.09
# 3    7.42
# 113  6.94
# 14   7.73
# 23   6.19
# 25   7.28
# 6    6.73
# 134  7.20
# 165  8.21
# 173  6.75
# 45   7.87
# 65   7.60
# 48   8.63
# 122  5.12
# 178  8.15
# 64   7.36
# 9    8.31
# 57   6.60
# 78   6.59
# 71   7.47
# 128  7.93
# 176  6.29
# 131  6.37
# 53   6.47

# %%
y_test
# Out:
# 112    4.10
# 29     3.49
# 182    2.08
# 199    2.33
# 193    1.94
# 85     1.48
# 10     1.86
# 54     3.09
# 115    4.21
# 35     2.87
# 12     3.65
# 92     4.00
# 13     2.89
# 126    2.60
# 174    2.99
# 2      3.25
# 44     1.86
# 3      3.67
# 113    2.37
# 14     3.42
# 23     2.48
# 25     3.65
# 6      2.60
# 134    2.83
# 165    4.08
# 173    2.56
# 45     3.58
# 65     3.81
# 48     4.09
# 122    2.01
# 178    3.63
# 64     2.92
# 9      3.51
# 57     1.94
# 78     2.21
# 71     3.34
# 128    3.34
# 176    3.23
# 131    2.01
# 53     2.61
# Name: package, dtype: float64

# %%
df.shape
# Out:
# (200, 2)

# %%
X_test.shape
X_train.shape
# Out:
# (160, 1)

# %%
# lr.predict(X_test.iloc[0]) ## error because we are sending 1d data but model wants 2D

# lr.predict(X_test.iloc[0].values.reshape(1,1))
lr.predict(X_test.iloc[1].values.reshape(1,1))
# Out:
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# d:\machine learning\ml-campus\.venv\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([3.09324469])

# %%
## our model is not giving fine prediction

# %%
plt.scatter(df['cgpa'],df['package'])
plt.plot(X_test,lr.predict(X_test),color= 'red')
plt.xlabel('CGPA')
plt.ylabel('Package(in LPA)')
# Out:
# Text(0, 0.5, 'Package(in LPA)')

# %%
slope_m = lr.coef_

# %%
intercept_b = lr.intercept_

# %%
## y = mx + b

slope_m * 8 + intercept_b ## this is the formula used by simple regression in the back ground
# Out:
# array([3.56750387])
